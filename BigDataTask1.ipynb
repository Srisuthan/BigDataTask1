# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('white_goods_fires_from_2009.csv')  # read the dataset

num_rows = df.shape[0]
print(f'The number of rows in the dataset is: {num_rows}')
# Out:
# The number of rows in the dataset is: 4721

# %%
# Display basic information about the dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4721 entries, 0 to 4720
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        4721 non-null   int64
#  1   Month                       4721 non-null   object
#  2   IncType                     4721 non-null   object
#  3   ParentPropertyType          4721 non-null   object
#  4   NumFireDeaths               4721 non-null   int64
#  5   NumAllFireInjuries          4721 non-null   int64
#  6   IncGeo_BoroughCode          4721 non-null   object
#  7   IncGeo_BoroughName          4721 non-null   object
#  8   IncGeo_WardCode             4720 non-null   object
#  9   IncGeo_WardName             4720 non-null   object
#  10  IgnitionSourcePower         4721 non-null   object
#  11  IgnitionSource              4721 non-null   object
#  12  ItemFirstIgnited            4721 non-null   object
#  13  LocationFireStarted         4721 non-null   object
#  14  ApplianceManufacturer       4196 non-null   object
#  15  ApplianceManufacturerOther  548 non-null    object
#  16  MainCauseModel              4125 non-null   object
# dtypes: int64(3), object(14)
# memory usage: 627.1+ KB
# None

# %%
# Display summary statistics
print(df.describe())
# Out:
#               Year  NumFireDeaths  NumAllFireInjuries
# count  4721.000000    4721.000000         4721.000000
# mean   2015.838805       0.018005            0.143190
# std       4.259444       1.037993            1.695283
# min    2009.000000       0.000000            0.000000
# 25%    2012.000000       0.000000            0.000000
# 50%    2016.000000       0.000000            0.000000
# 75%    2019.000000       0.000000            0.000000
# max    2024.000000      71.000000          109.000000

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# Year                             0
# Month                            0
# IncType                          0
# ParentPropertyType               0
# NumFireDeaths                    0
# NumAllFireInjuries               0
# IncGeo_BoroughCode               0
# IncGeo_BoroughName               0
# IncGeo_WardCode                  1
# IncGeo_WardName                  1
# IgnitionSourcePower              0
# IgnitionSource                   0
# ItemFirstIgnited                 0
# LocationFireStarted              0
# ApplianceManufacturer          525
# ApplianceManufacturerOther    4173
# MainCauseModel                 596
# dtype: int64

# %%
# Check for duplicate rows
duplicate_rows = df[df.duplicated()]

# Display duplicate rows, if any
print("Duplicate Rows except first occurrence:")
print(duplicate_rows)
# Out:
# Duplicate Rows except first occurrence:
#      Year Month       IncType ParentPropertyType  NumFireDeaths  \
# 293  2009  July  Primary Fire   Residential Home              0
#
#      NumAllFireInjuries IncGeo_BoroughCode IncGeo_BoroughName IncGeo_WardCode  \
# 293                   0          E09000003             Barnet       E05013634
#
#     IncGeo_WardName IgnitionSourcePower IgnitionSource   ItemFirstIgnited  \
# 293     Cricklewood         Electricity     Dishwasher  Internal Fittings
#
#     LocationFireStarted ApplianceManufacturer ApplianceManufacturerOther  \
# 293             Kitchen               INDESIT                        NaN
#
#     MainCauseModel
# 293            530

# %%
# Remove duplicate rows
df = df.drop_duplicates()

num_rows = df.shape[0]
print(f'The number of rows in the dataset is: {num_rows}')
# Out:
# The number of rows in the dataset is: 4720

# %%
# Read first five rows
df.head()
# Out:
#    Year   Month       IncType               ParentPropertyType  NumFireDeaths  \
# 0  2009    June  Primary Fire  Purpose Built Flats/Maisonettes              0
# 1  2009    July  Primary Fire  Purpose Built Flats/Maisonettes              0
# 2  2009    July  Primary Fire  Purpose Built Flats/Maisonettes              0
# 3  2009  August  Primary Fire  Purpose Built Flats/Maisonettes              0
# 4  2009    June  Primary Fire  Purpose Built Flats/Maisonettes              0
#
#    NumAllFireInjuries IncGeo_BoroughCode    IncGeo_BoroughName  \
# 0                   0          E09000033           Westminster
# 1                   0          E09000007                Camden
# 2                   0          E09000021  Kingston upon Thames
# 3                   0          E09000030         Tower Hamlets
# 4                   1          E09000016              Havering
#
#   IncGeo_WardCode IncGeo_WardName IgnitionSourcePower   IgnitionSource  \
# 0       E05013807  Vincent Square         Electricity  Washing machine
# 1       E05013654   Camden Square         Electricity  Washing machine
# 2       E05013932     Coombe Hill         Electricity  Washing machine
# 3       E05009334   Stepney Green         Electricity   Fridge/Freezer
# 4       E05013969        Elm Park         Electricity   Fridge/Freezer
#
#               ItemFirstIgnited LocationFireStarted ApplianceManufacturer  \
# 0            Wiring insulation             Kitchen                HOOVER
# 1  Plastic - raw material only             Kitchen                 CANDY
# 2            Wiring insulation             Kitchen                 CANDY
# 3  Plastic - raw material only             Bedroom                   LEC
# 4  Plastic - raw material only       Corridor/Hall                 BEJAM
#
#   ApplianceManufacturerOther                  MainCauseModel
# 0                        NaN                   Quattro AS110
# 1                        NaN                   Aquaviva 120T
# 2                        NaN                             450
# 3                        NaN                       not known
# 4                        NaN  Fridge Freezer model not known

# %%
# Read last fives rows
df.tail()
# Out:
#       Year     Month       IncType               ParentPropertyType  \
# 4716  2024   January  Primary Fire  Purpose Built Flats/Maisonettes
# 4717  2024   January  Primary Fire  Purpose Built Flats/Maisonettes
# 4718  2024  February  Primary Fire  Purpose Built Flats/Maisonettes
# 4719  2024  February  Primary Fire  Purpose Built Flats/Maisonettes
# 4720  2024  February  Primary Fire  Purpose Built Flats/Maisonettes
#
#       NumFireDeaths  NumAllFireInjuries IncGeo_BoroughCode  \
# 4716              0                   0          E09000016
# 4717              0                   0          E09000027
# 4718              0                   0          E09000019
# 4719              0                   0          E09000017
# 4720              0                   0          E09000016
#
#         IncGeo_BoroughName IncGeo_WardCode         IncGeo_WardName  \
# 4716              HAVERING       E05013975                  HEATON
# 4717  RICHMOND UPON THAMES       E05013778                 HAMPTON
# 4718             ISLINGTON       E05013697                 ARSENAL
# 4719            HILLINGDON       E05013569              HAYES TOWN
# 4720              HAVERING       E05013980  RUSH GREEN & CROWLANDS
#
#      IgnitionSourcePower         IgnitionSource             ItemFirstIgnited  \
# 4716         Electricity  Washer/Dryer combined  Plastic - raw material only
# 4717         Electricity  Washer/Dryer combined                     Clothing
# 4718         Electricity             Dishwasher            Wiring insulation
# 4719         Electricity        Washing machine  Plastic - raw material only
# 4720         Electricity        Washing machine                         None
#
#      LocationFireStarted ApplianceManufacturer ApplianceManufacturerOther  \
# 4716        Utility room                HOOVER                        NaN
# 4717             Kitchen               INDESIT                        NaN
# 4718             Kitchen                 BOSCH                        NaN
# 4719             Kitchen              HOTPOINT                        NaN
# 4720             Kitchen                 SHARP                        NaN
#
#      MainCauseModel
# 4716       HLW585DC
# 4717   IWDE126 (UK)
# 4718      Classicxx
# 4719          t-200
# 4720  ES-NDIB7141WD
